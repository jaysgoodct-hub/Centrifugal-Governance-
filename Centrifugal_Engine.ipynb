# %% [markdown]
# # 🌌 Centrifugal Governance: Core Engine Simulation
# ### Researcher: Jason Hultberg
# Calculations for the **1.3333-hr pulse** and **72 RPM** atmospheric venting.

# %%
import math
rpm = 72
pulse = 1.3333
print(f'Engine Speed: {rpm} RPM')
print(f'Atmospheric Pulse: {pulse} hours')
for i in range(1, 11):
    print(f'Pulse {i}: {round(i * pulse, 4)} hrs')
